# %% [markdown]
# # Training: CNN → ONNX (Python)
#
# Обучение простого 1D‑CNN и экспорт в ONNX для инференса в C#. Без LSTM/seq2seq.

# %%
import sys, subprocess

def pip_install(packages):
    subprocess.check_call([sys.executable, "-m", "pip", "install", "--upgrade", *packages])

pip_install(["torch", "onnx", "onnxruntime", "onnxscript"])
# при необходимости добавьте сюда другие пакеты (например, "numpy"), если они отсутствуют в окружении

# %%
# %run train_cnn.py
